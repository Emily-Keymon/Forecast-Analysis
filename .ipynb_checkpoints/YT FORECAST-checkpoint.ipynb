# %% [markdown]
# ## YT FORECAST
# *  Create a Forecast Analysis Dashboard for financial forecasting

# %% [markdown]
# ## Extract/Transform Data

# %%
#Import libraries
import pandas as pd

# %%
# Load JAX OPEN ORDERS from Resources folder
file = "Resources/JAX OPEN ORDERS.xlsx"

# Read excel file into DataFrame, set ITEM as index
jax_data = pd.read_excel(file, index_col="Item")

#Check dataframe
jax_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type  Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915    1   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540    1   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876    1   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781    1   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913    1   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Material Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...    1993.78327
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...     851.62450
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...    1376.55100
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...    2652.35089
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...      13.65025
#
#              Material OH Cost  Resource Cost  Overhead Cost  OSP Cost  \
# Item
# YT01474-804               NaN      214.83970      951.05812       NaN
# YT01788-804               NaN      185.49540      821.49932       NaN
# YT02190-806               NaN      189.63924      838.22607      42.0
# YT02248-805               NaN      237.36058     1040.09375       NaN
# YT02706-816               NaN        6.56999       29.43813       NaN
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  Address Line 4
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US             NaN
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US             NaN
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US             NaN
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US             NaN
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US             NaN
#
# [5 rows x 25 columns]

# %%
# Check count
jax_data.count()
# Out:
# Item Description      229
# Planner               229
# Order Type            229
# Order#                229
# Ln#                   229
# Ordered Date          229
# Line Creation Date    229
# Line Update Date      229
# Request Date          229
# Schedule Date         229
# Promise Date          229
# Open Qty              229
# Price                 229
# Extended Price        229
# Item Cost             229
# Material Cost         229
# Material OH Cost        0
# Resource Cost         191
# Overhead Cost         189
# OSP Cost               44
# Customer Name         229
# Address Line 1        229
# Address Line 2        229
# Address Line 3        186
# Address Line 4          0
# dtype: int64

# %%
# Add ORG column
jax_data["ORG"] = "JAX"
jax_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type  Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915    1   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540    1   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876    1   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781    1   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913    1   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Material OH Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...              NaN
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...              NaN
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...              NaN
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...              NaN
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...              NaN
#
#              Resource Cost  Overhead Cost  OSP Cost  \
# Item
# YT01474-804      214.83970      951.05812       NaN
# YT01788-804      185.49540      821.49932       NaN
# YT02190-806      189.63924      838.22607      42.0
# YT02248-805      237.36058     1040.09375       NaN
# YT02706-816        6.56999       29.43813       NaN
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
#
#              Address Line 4  ORG
# Item
# YT01474-804             NaN  JAX
# YT01788-804             NaN  JAX
# YT02190-806             NaN  JAX
# YT02248-805             NaN  JAX
# YT02706-816             NaN  JAX
#
# [5 rows x 26 columns]

# %%
# Load LEX OPEN ORDERS from Resources folder
file = "Resources/LEX OPEN ORDERS.xlsx"

# Read excel file into DataFrame, set ITEM as index
lex_data = pd.read_excel(file, index_col="Item")

#Check dataframe
lex_data.head()
# Out:
#                                           Item Description Planner  \
# Item
# BE4900135000                      MATCHBELT SET 2500x6 SPC      BL
# BE4900135000                      MATCHBELT SET 2500x6 SPC      BL
# YT#500826     HB.32.N.X.1.2.4.2.15.M.X.X.X.X.G.G.C.X.X.X.X       4
# YT#500827     HB.44.N.X.1.2.5.2.20.M.X.X.X.X.G.G.C.X.X.X.X       4
# YT#500836     HB.44.N.X.1.2.8.2.40.H.X.X.X.X.X.X.X.X.X.X.X       4
#
#                      Order Type    Order#  Ln# Ordered Date  \
# Item
# BE4900135000       YTS-DOMESTIC  563275.0  3.0   2021-02-03
# BE4900135000       YTS-DOMESTIC  563961.0  4.0   2021-04-19
# YT#500826     YTS-INTERNATIONAL  559636.0  2.0   2020-01-06
# YT#500827     YTS-INTERNATIONAL  559636.0  7.0   2020-01-06
# YT#500836          YTS-DOMESTIC  563828.0  2.0   2021-04-06
#
#              Line Creation Date Line Update Date Request Date Schedule Date  \
# Item
# BE4900135000         2021-02-03       2021-03-16   2021-03-22    2021-05-19
# BE4900135000         2021-04-19       2021-04-19   2021-06-25    2021-06-04
# YT#500826            2020-01-06       2021-01-06   2021-10-22    2021-10-15
# YT#500827            2020-01-06       2021-01-06   2021-10-22    2021-10-15
# YT#500836            2021-04-06       2021-04-14   2021-05-20    2021-05-04
#
#               ... Material Cost  Material OH Cost  Resource Cost  \
# Item          ...
# BE4900135000  ...     106.96000               NaN            NaN
# BE4900135000  ...     106.96000               NaN            NaN
# YT#500826     ...    8195.66905               NaN      844.11838
# YT#500827     ...   10642.10115               NaN      951.30543
# YT#500836     ...   14446.93230               NaN      965.22693
#
#               Overhead Cost  OSP Cost                       Customer Name  \
# Item
# BE4900135000            NaN       NaN                         C H BULL CO
# BE4900135000            NaN       NaN                         C H BULL CO
# YT#500826        3649.16565   0.00012  BOBCAT BAHAMAS-DIV. CAVALIER CONST
# YT#500827        4121.59291   0.00012  BOBCAT BAHAMAS-DIV. CAVALIER CONST
# YT#500836        4179.10753   0.00012           DEHN ENGINEERING SALES CO
#
#                     Address Line 1        Address Line 2  \
# Item
# BE4900135000      6141 KATELLA AVE             SUITE 200
# BE4900135000      6141 KATELLA AVE             SUITE 200
# YT#500826     9505 NW 108TH AVENUE  Medley,FL 33178 - US
# YT#500827     9505 NW 108TH AVENUE  Medley,FL 33178 - US
# YT#500836        4857 NW LAKE ROAD   Camas,WA 98607 - US
#
#                      Address Line 3  Address Line 4
# Item
# BE4900135000  Cypress,CA 90630 - US             NaN
# BE4900135000  Cypress,CA 90630 - US             NaN
# YT#500826                       NaN             NaN
# YT#500827                       NaN             NaN
# YT#500836                       NaN             NaN
#
# [5 rows x 25 columns]

# %%
# Check count
lex_data.count()
# Out:
# Item Description      632
# Planner               632
# Order Type            632
# Order#                632
# Ln#                   632
# Ordered Date          632
# Line Creation Date    632
# Line Update Date      632
# Request Date          632
# Schedule Date         632
# Promise Date          632
# Open Qty              632
# Price                 632
# Extended Price        633
# Item Cost             632
# Material Cost         624
# Material OH Cost        0
# Resource Cost         510
# Overhead Cost         496
# OSP Cost              277
# Customer Name         632
# Address Line 1        632
# Address Line 2        632
# Address Line 3        485
# Address Line 4          0
# dtype: int64

# %%
# Add ORG column
lex_data["ORG"] = "LEX"
lex_data.head()
# Out:
#                                           Item Description Planner  \
# Item
# BE4900135000                      MATCHBELT SET 2500x6 SPC      BL
# BE4900135000                      MATCHBELT SET 2500x6 SPC      BL
# YT#500826     HB.32.N.X.1.2.4.2.15.M.X.X.X.X.G.G.C.X.X.X.X       4
# YT#500827     HB.44.N.X.1.2.5.2.20.M.X.X.X.X.G.G.C.X.X.X.X       4
# YT#500836     HB.44.N.X.1.2.8.2.40.H.X.X.X.X.X.X.X.X.X.X.X       4
#
#                      Order Type    Order#  Ln# Ordered Date  \
# Item
# BE4900135000       YTS-DOMESTIC  563275.0  3.0   2021-02-03
# BE4900135000       YTS-DOMESTIC  563961.0  4.0   2021-04-19
# YT#500826     YTS-INTERNATIONAL  559636.0  2.0   2020-01-06
# YT#500827     YTS-INTERNATIONAL  559636.0  7.0   2020-01-06
# YT#500836          YTS-DOMESTIC  563828.0  2.0   2021-04-06
#
#              Line Creation Date Line Update Date Request Date Schedule Date  \
# Item
# BE4900135000         2021-02-03       2021-03-16   2021-03-22    2021-05-19
# BE4900135000         2021-04-19       2021-04-19   2021-06-25    2021-06-04
# YT#500826            2020-01-06       2021-01-06   2021-10-22    2021-10-15
# YT#500827            2020-01-06       2021-01-06   2021-10-22    2021-10-15
# YT#500836            2021-04-06       2021-04-14   2021-05-20    2021-05-04
#
#               ... Material OH Cost  Resource Cost  Overhead Cost  OSP Cost  \
# Item          ...
# BE4900135000  ...              NaN            NaN            NaN       NaN
# BE4900135000  ...              NaN            NaN            NaN       NaN
# YT#500826     ...              NaN      844.11838     3649.16565   0.00012
# YT#500827     ...              NaN      951.30543     4121.59291   0.00012
# YT#500836     ...              NaN      965.22693     4179.10753   0.00012
#
#                                    Customer Name        Address Line 1  \
# Item
# BE4900135000                         C H BULL CO      6141 KATELLA AVE
# BE4900135000                         C H BULL CO      6141 KATELLA AVE
# YT#500826     BOBCAT BAHAMAS-DIV. CAVALIER CONST  9505 NW 108TH AVENUE
# YT#500827     BOBCAT BAHAMAS-DIV. CAVALIER CONST  9505 NW 108TH AVENUE
# YT#500836              DEHN ENGINEERING SALES CO     4857 NW LAKE ROAD
#
#                     Address Line 2         Address Line 3  Address Line 4  ORG
# Item
# BE4900135000             SUITE 200  Cypress,CA 90630 - US             NaN  LEX
# BE4900135000             SUITE 200  Cypress,CA 90630 - US             NaN  LEX
# YT#500826     Medley,FL 33178 - US                    NaN             NaN  LEX
# YT#500827     Medley,FL 33178 - US                    NaN             NaN  LEX
# YT#500836      Camas,WA 98607 - US                    NaN             NaN  LEX
#
# [5 rows x 26 columns]

# %%
# Merge jax_data and lex_data
both = [jax_data, lex_data]
total_data = pd.concat(both)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Material OH Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...              NaN
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...              NaN
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...              NaN
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...              NaN
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...              NaN
#
#              Resource Cost  Overhead Cost  OSP Cost  \
# Item
# YT01474-804      214.83970      951.05812       NaN
# YT01788-804      185.49540      821.49932       NaN
# YT02190-806      189.63924      838.22607      42.0
# YT02248-805      237.36058     1040.09375       NaN
# YT02706-816        6.56999       29.43813       NaN
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
#
#              Address Line 4  ORG
# Item
# YT01474-804             NaN  JAX
# YT01788-804             NaN  JAX
# YT02190-806             NaN  JAX
# YT02248-805             NaN  JAX
# YT02706-816             NaN  JAX
#
# [5 rows x 26 columns]

# %%
# Check count
total_data.count()
# Out:
# Item Description      861
# Planner               861
# Order Type            861
# Order#                861
# Ln#                   861
# Ordered Date          861
# Line Creation Date    861
# Line Update Date      861
# Request Date          861
# Schedule Date         861
# Promise Date          861
# Open Qty              861
# Price                 861
# Extended Price        862
# Item Cost             861
# Material Cost         853
# Material OH Cost        0
# Resource Cost         701
# Overhead Cost         685
# OSP Cost              321
# Customer Name         861
# Address Line 1        861
# Address Line 2        861
# Address Line 3        671
# Address Line 4          0
# ORG                   862
# dtype: int64

# %%
# Check data types
total_data.dtypes
# Out:
# Item Description              object
# Planner                       object
# Order Type                    object
# Order#                       float64
# Ln#                          float64
# Ordered Date          datetime64[ns]
# Line Creation Date    datetime64[ns]
# Line Update Date      datetime64[ns]
# Request Date          datetime64[ns]
# Schedule Date         datetime64[ns]
# Promise Date          datetime64[ns]
# Open Qty                     float64
# Price                        float64
# Extended Price               float64
# Item Cost                    float64
# Material Cost                float64
# Material OH Cost             float64
# Resource Cost                float64
# Overhead Cost                float64
# OSP Cost                     float64
# Customer Name                 object
# Address Line 1                object
# Address Line 2                object
# Address Line 3                object
# Address Line 4               float64
# ORG                           object
# dtype: object

# %%
# Change columns (take out spaces for future use)
total_data = total_data.rename(columns = {"Open Qty": "Open_Qty",
                                          "Extended Price": "Extended_Price",
                                          "Item Cost": "Item_Cost",
                                          "Material Cost": "Material_Cost",
                                          "Material OH Cost": "Material_OH_Cost",
                                          "Resource Cost": "Resource_Cost",
                                          "Overhead Cost": "Overhead_Cost",
                                          "OSP Cost": "OSP_Cost"})
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Material_OH_Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...              NaN
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...              NaN
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...              NaN
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...              NaN
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...              NaN
#
#              Resource_Cost  Overhead_Cost  OSP_Cost  \
# Item
# YT01474-804      214.83970      951.05812       NaN
# YT01788-804      185.49540      821.49932       NaN
# YT02190-806      189.63924      838.22607      42.0
# YT02248-805      237.36058     1040.09375       NaN
# YT02706-816        6.56999       29.43813       NaN
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
#
#              Address Line 4  ORG
# Item
# YT01474-804             NaN  JAX
# YT01788-804             NaN  JAX
# YT02190-806             NaN  JAX
# YT02248-805             NaN  JAX
# YT02706-816             NaN  JAX
#
# [5 rows x 26 columns]

# %%
# Check data types
total_data.dtypes
# Out:
# Item Description              object
# Planner                       object
# Order Type                    object
# Order#                       float64
# Ln#                          float64
# Ordered Date          datetime64[ns]
# Line Creation Date    datetime64[ns]
# Line Update Date      datetime64[ns]
# Request Date          datetime64[ns]
# Schedule Date         datetime64[ns]
# Promise Date          datetime64[ns]
# Open_Qty                     float64
# Price                        float64
# Extended_Price               float64
# Item_Cost                    float64
# Material_Cost                float64
# Material_OH_Cost             float64
# Resource_Cost                float64
# Overhead_Cost                float64
# OSP_Cost                     float64
# Customer Name                 object
# Address Line 1                object
# Address Line 2                object
# Address Line 3                object
# Address Line 4               float64
# ORG                           object
# dtype: object

# %%
# Extended Cost calculation
total_data["Extended_Cost"] = total_data.Open_Qty * total_data.Item_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Resource_Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...     214.83970
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...     185.49540
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...     189.63924
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...     237.36058
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...       6.56999
#
#              Overhead_Cost  OSP_Cost                     Customer Name  \
# Item
# YT01474-804      951.05812       NaN  WABCO-KANSAS CITY SERVICE CENTER
# YT01788-804      821.49932       NaN     PROGRESS RAIL LOCOMOTIVE INC.
# YT02190-806      838.22607      42.0  WABCO-KANSAS CITY SERVICE CENTER
# YT02248-805     1040.09375       NaN                MOTIVE POWER-BOISE
# YT02706-816       29.43813       NaN  WABCO-KANSAS CITY SERVICE CENTER
#
#                      Address Line 1          Address Line 2  \
# Item
# YT01474-804            4800 DERAMUS                   (JAX)
# YT01788-804  PROGRESS RAIL PARTS DC     16101 S. OUTER ROAD
# YT02190-806            4800 DERAMUS                   (JAX)
# YT02248-805     901 FRANKLIN AVENUE  BUILDING 18 SOUTH DOCK
# YT02706-816            4800 DERAMUS                   (JAX)
#
#                         Address Line 3  Address Line 4  ORG  Extended_Cost
# Item
# YT01474-804  KANSAS CITY,MO 64120 - US             NaN  JAX        6319.36
# YT01788-804       Belton,MO 64012 - US             NaN  JAX       14868.96
# YT02190-806  KANSAS CITY,MO 64120 - US             NaN  JAX       24464.20
# YT02248-805         Erie,PA 16531 - US             NaN  JAX        7859.62
# YT02706-816  KANSAS CITY,MO 64120 - US             NaN  JAX        2483.00
#
# [5 rows x 27 columns]

# %%
# Material calculation (Open Qty * Material Cost)
total_data["Material"] = total_data.Open_Qty * total_data.Material_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Overhead_Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...     951.05812
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...     821.49932
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...     838.22607
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...    1040.09375
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...      29.43813
#
#              OSP_Cost                     Customer Name  \
# Item
# YT01474-804       NaN  WABCO-KANSAS CITY SERVICE CENTER
# YT01788-804       NaN     PROGRESS RAIL LOCOMOTIVE INC.
# YT02190-806      42.0  WABCO-KANSAS CITY SERVICE CENTER
# YT02248-805       NaN                MOTIVE POWER-BOISE
# YT02706-816       NaN  WABCO-KANSAS CITY SERVICE CENTER
#
#                      Address Line 1          Address Line 2  \
# Item
# YT01474-804            4800 DERAMUS                   (JAX)
# YT01788-804  PROGRESS RAIL PARTS DC     16101 S. OUTER ROAD
# YT02190-806            4800 DERAMUS                   (JAX)
# YT02248-805     901 FRANKLIN AVENUE  BUILDING 18 SOUTH DOCK
# YT02706-816            4800 DERAMUS                   (JAX)
#
#                         Address Line 3  Address Line 4  ORG  Extended_Cost  \
# Item
# YT01474-804  KANSAS CITY,MO 64120 - US             NaN  JAX        6319.36
# YT01788-804       Belton,MO 64012 - US             NaN  JAX       14868.96
# YT02190-806  KANSAS CITY,MO 64120 - US             NaN  JAX       24464.20
# YT02248-805         Erie,PA 16531 - US             NaN  JAX        7859.62
# YT02706-816  KANSAS CITY,MO 64120 - US             NaN  JAX        2483.00
#
#              Material
# Item
# YT01474-804   3987.56
# YT01788-804   6812.96
# YT02190-806  13765.50
# YT02248-805   5304.70
# YT02706-816    682.50
#
# [5 rows x 28 columns]

# %%
# Labor calculation (Open Qty * Resource Cost)
total_data["Labor"] = total_data.Open_Qty * total_data.Resource_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... OSP_Cost  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...      NaN
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...      NaN
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...     42.0
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...      NaN
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...      NaN
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
#
#              Address Line 4  ORG  Extended_Cost  Material    Labor
# Item
# YT01474-804             NaN  JAX        6319.36   3987.56   429.68
# YT01788-804             NaN  JAX       14868.96   6812.96  1484.00
# YT02190-806             NaN  JAX       24464.20  13765.50  1896.40
# YT02248-805             NaN  JAX        7859.62   5304.70   474.72
# YT02706-816             NaN  JAX        2483.00    682.50   328.50
#
# [5 rows x 29 columns]

# %%
# Overhead calculation (Open Qty * Overhead Cost)
total_data["Overhead"] = total_data.Open_Qty * total_data.Overhead_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ...  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...
#
#                                 Customer Name          Address Line 1  \
# Item
# YT01474-804  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT01788-804     PROGRESS RAIL LOCOMOTIVE INC.  PROGRESS RAIL PARTS DC
# YT02190-806  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
# YT02248-805                MOTIVE POWER-BOISE     901 FRANKLIN AVENUE
# YT02706-816  WABCO-KANSAS CITY SERVICE CENTER            4800 DERAMUS
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
#
#              Address Line 4  ORG  Extended_Cost  Material    Labor  Overhead
# Item
# YT01474-804             NaN  JAX        6319.36   3987.56   429.68   1902.12
# YT01788-804             NaN  JAX       14868.96   6812.96  1484.00   6572.00
# YT02190-806             NaN  JAX       24464.20  13765.50  1896.40   8382.30
# YT02248-805             NaN  JAX        7859.62   5304.70   474.72   2080.18
# YT02706-816             NaN  JAX        2483.00    682.50   328.50   1472.00
#
# [5 rows x 30 columns]

# %%
# Outside processing calculation (Open Qty * OSP Cost)
total_data["OSP"] = total_data.Open_Qty * total_data.OSP_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ...  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...
#
#                      Address Line 1          Address Line 2  \
# Item
# YT01474-804            4800 DERAMUS                   (JAX)
# YT01788-804  PROGRESS RAIL PARTS DC     16101 S. OUTER ROAD
# YT02190-806            4800 DERAMUS                   (JAX)
# YT02248-805     901 FRANKLIN AVENUE  BUILDING 18 SOUTH DOCK
# YT02706-816            4800 DERAMUS                   (JAX)
#
#                         Address Line 3  Address Line 4  ORG  Extended_Cost  \
# Item
# YT01474-804  KANSAS CITY,MO 64120 - US             NaN  JAX        6319.36
# YT01788-804       Belton,MO 64012 - US             NaN  JAX       14868.96
# YT02190-806  KANSAS CITY,MO 64120 - US             NaN  JAX       24464.20
# YT02248-805         Erie,PA 16531 - US             NaN  JAX        7859.62
# YT02706-816  KANSAS CITY,MO 64120 - US             NaN  JAX        2483.00
#
#              Material    Labor  Overhead    OSP
# Item
# YT01474-804   3987.56   429.68   1902.12    NaN
# YT01788-804   6812.96  1484.00   6572.00    NaN
# YT02190-806  13765.50  1896.40   8382.30  420.0
# YT02248-805   5304.70   474.72   2080.18    NaN
# YT02706-816    682.50   328.50   1472.00    NaN
#
# [5 rows x 31 columns]

# %%
# Calculate COGS (Material Cost + Labor + Overhead Cost + Outside Processing (OSP Cost))
#total_data["COGS"] = total_data.Material_Cost + total_data.Overhead_Cost + total_data.OSP_Cost
total_data["Total"] = total_data.Material_Cost.round(2) + total_data.Overhead_Cost.round(2)
total_data
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
# ...                                                       ...     ...
# YTNRE                         NON-RECURRING EXPENSE\t\t\t\t\t    CUST
# YTPPAP                              CUSTOMER PPAP REQUIREMENT    CUST
# YTPPAP                              CUSTOMER PPAP REQUIREMENT    CUST
# YTPPAP                              CUSTOMER PPAP REQUIREMENT    CUST
# NaN                                                       NaN     NaN
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
# ...                   ...       ...  ...          ...                ...
# YTNRE        YTS-DOMESTIC  563334.0  2.0   2021-02-09         2021-02-09
# YTPPAP       YTS-DOMESTIC  563464.0  2.0   2021-02-24         2021-02-24
# YTPPAP       YTS-DOMESTIC  563160.0  2.0   2021-01-21         2021-02-11
# YTPPAP       YTS-DOMESTIC  563913.0  2.0   2021-04-12         2021-04-12
# NaN                   NaN       NaN  NaN          NaT                NaT
#
#             Line Update Date Request Date Schedule Date  ...  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...
# ...                      ...          ...           ...  ...
# YTNRE             2021-03-23   2021-06-14    2021-06-03  ...
# YTPPAP            2021-03-17   2021-04-28    2021-04-22  ...
# YTPPAP            2021-02-12   2021-06-02    2021-05-25  ...
# YTPPAP            2021-04-13   2021-07-02    2021-06-18  ...
# NaN                      NaT          NaT           NaT  ...
#
#                      Address Line 2             Address Line 3  \
# Item
# YT01474-804                   (JAX)  KANSAS CITY,MO 64120 - US
# YT01788-804     16101 S. OUTER ROAD       Belton,MO 64012 - US
# YT02190-806                   (JAX)  KANSAS CITY,MO 64120 - US
# YT02248-805  BUILDING 18 SOUTH DOCK         Erie,PA 16531 - US
# YT02706-816                   (JAX)  KANSAS CITY,MO 64120 - US
# ...                             ...                        ...
# YTNRE        1950 NORTH LOOP AVENUE       CASPER,WY 82601 - US
# YTPPAP        3701 STATE RD 26 EAST    LAFAYETTE,IN 47905 - US
# YTPPAP        3701 STATE RD 26 EAST    LAFAYETTE,IN 47905 - US
# YTPPAP          7033 CENTRAL AVENUE      Fridley,MN 55432 - US
# NaN                             NaN                        NaN
#
#              Address Line 4  ORG  Extended_Cost  Material    Labor  Overhead  \
# Item
# YT01474-804             NaN  JAX        6319.36   3987.56   429.68   1902.12
# YT01788-804             NaN  JAX       14868.96   6812.96  1484.00   6572.00
# YT02190-806             NaN  JAX       24464.20  13765.50  1896.40   8382.30
# YT02248-805             NaN  JAX        7859.62   5304.70   474.72   2080.18
# YT02706-816             NaN  JAX        2483.00    682.50   328.50   1472.00
# ...                     ...  ...            ...       ...      ...       ...
# YTNRE                   NaN  LEX           0.00       NaN      NaN       NaN
# YTPPAP                  NaN  LEX           0.00       NaN      NaN       NaN
# YTPPAP                  NaN  LEX           0.00       NaN      NaN       NaN
# YTPPAP                  NaN  LEX           0.00       NaN      NaN       NaN
# NaN                     NaN  LEX            NaN       NaN      NaN       NaN
#
#                OSP    Total
# Item
# YT01474-804    NaN  2944.84
# YT01788-804    NaN  1673.12
# YT02190-806  420.0  2214.78
# YT02248-805    NaN  3692.44
# YT02706-816    NaN    43.09
# ...            ...      ...
# YTNRE          NaN      NaN
# YTPPAP         NaN      NaN
# YTPPAP         NaN      NaN
# YTPPAP         NaN      NaN
# NaN            NaN      NaN
#
# [862 rows x 32 columns]

# %%
# Check data types
total_data.dtypes
# Out:
# Item Description              object
# Planner                       object
# Order Type                    object
# Order#                       float64
# Ln#                          float64
# Ordered Date          datetime64[ns]
# Line Creation Date    datetime64[ns]
# Line Update Date      datetime64[ns]
# Request Date          datetime64[ns]
# Schedule Date         datetime64[ns]
# Promise Date          datetime64[ns]
# Open_Qty                     float64
# Price                        float64
# Extended_Price               float64
# Item_Cost                    float64
# Material_Cost                float64
# Material_OH_Cost             float64
# Resource_Cost                float64
# Overhead_Cost                float64
# OSP_Cost                     float64
# Customer Name                 object
# Address Line 1                object
# Address Line 2                object
# Address Line 3                object
# Address Line 4               float64
# ORG                           object
# Extended_Cost                float64
# Material                     float64
# Labor                        float64
# Overhead                     float64
# OSP                          float64
# Total                        float64
# dtype: object

# %%
# Calculate Gross Margin Dollars (Sales - COGS:  Extended Price - Extended Cost)
total_data["Margin"] = total_data.Extended_Price.round(2) - total_data.Extended_Cost.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ...  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...
#
#                         Address Line 3  Address Line 4  ORG  Extended_Cost  \
# Item
# YT01474-804  KANSAS CITY,MO 64120 - US             NaN  JAX        6319.36
# YT01788-804       Belton,MO 64012 - US             NaN  JAX       14868.96
# YT02190-806  KANSAS CITY,MO 64120 - US             NaN  JAX       24464.20
# YT02248-805         Erie,PA 16531 - US             NaN  JAX        7859.62
# YT02706-816  KANSAS CITY,MO 64120 - US             NaN  JAX        2483.00
#
#              Material    Labor  Overhead    OSP    Total   Margin
# Item
# YT01474-804   3987.56   429.68   1902.12    NaN  2944.84     0.00
# YT01788-804   6812.96  1484.00   6572.00    NaN  1673.12  6371.04
# YT02190-806  13765.50  1896.40   8382.30  420.0  2214.78 -1339.91
# YT02248-805   5304.70   474.72   2080.18    NaN  3692.44  2265.02
# YT02706-816    682.50   328.50   1472.00    NaN    43.09    -0.08
#
# [5 rows x 33 columns]

# %%
# Calculate Gross Margin Percent (Margin / Extended Price)
total_data["Margin%"] = total_data.Margin.round(2) / total_data.Extended_Price.round(2)
total_data.head()
# Out:
#                                              Item Description Planner  \
# Item
# YT01474-804    D8 RADIATOR YTF 108 XP CR VCI - FINAL ASSEMBLY       3
# YT01788-804    S6 RADIATOR YTF 106 XP CR VCI - FINAL ASSEMBLY       3
# YT02190-806   D6 RADIATOR YTF 106 PAL CB BOX - FINAL ASSEMBLY       3
# YT02248-805  T8 RADIATOR YTF 108 STD PAL/PLY - FINAL ASSEMBLY       3
# YT02706-816                BANK SPACER 11.12 55.00 16G GE/TCS      SV
#
#                Order Type    Order#  Ln# Ordered Date Line Creation Date  \
# Item
# YT01474-804  YTS-INTERNAL  110915.0  1.0   2021-04-13         2021-04-13
# YT01788-804  YTS-DOMESTIC  563540.0  1.0   2021-03-03         2021-03-03
# YT02190-806  YTS-INTERNAL  110876.0  1.0   2021-03-03         2021-03-03
# YT02248-805  YTS-DOMESTIC  563781.0  1.0   2021-03-29         2021-03-29
# YT02706-816  YTS-INTERNAL  110913.0  1.0   2021-04-08         2021-04-08
#
#             Line Update Date Request Date Schedule Date  ... Address Line 4  \
# Item                                                     ...
# YT01474-804       2021-04-21   2031-04-27    2021-06-03  ...            NaN
# YT01788-804       2021-03-04   2021-05-17    2021-05-13  ...            NaN
# YT02190-806       2021-03-11   2021-03-17    2021-04-29  ...            NaN
# YT02248-805       2021-04-01   2021-03-29    2021-04-28  ...            NaN
# YT02706-816       2021-04-13   2031-05-06    2021-05-05  ...            NaN
#
#              ORG  Extended_Cost  Material    Labor  Overhead    OSP    Total  \
# Item
# YT01474-804  JAX        6319.36   3987.56   429.68   1902.12    NaN  2944.84
# YT01788-804  JAX       14868.96   6812.96  1484.00   6572.00    NaN  1673.12
# YT02190-806  JAX       24464.20  13765.50  1896.40   8382.30  420.0  2214.78
# YT02248-805  JAX        7859.62   5304.70   474.72   2080.18    NaN  3692.44
# YT02706-816  JAX        2483.00    682.50   328.50   1472.00    NaN    43.09
#
#               Margin   Margin%
# Item
# YT01474-804     0.00  0.000000
# YT01788-804  6371.04  0.299955
# YT02190-806 -1339.91 -0.057944
# YT02248-805  2265.02  0.223714
# YT02706-816    -0.08 -0.000032
#
# [5 rows x 34 columns]

# %%
#Update margin to %
#total_data["Margin%"].astype("{:,2f}")

# %%
# Check data types
total_data.dtypes
# Out:
# Item Description              object
# Planner                       object
# Order Type                    object
# Order#                       float64
# Ln#                          float64
# Ordered Date          datetime64[ns]
# Line Creation Date    datetime64[ns]
# Line Update Date      datetime64[ns]
# Request Date          datetime64[ns]
# Schedule Date         datetime64[ns]
# Promise Date          datetime64[ns]
# Open_Qty                     float64
# Price                        float64
# Extended_Price               float64
# Item_Cost                    float64
# Material_Cost                float64
# Material_OH_Cost             float64
# Resource_Cost                float64
# Overhead_Cost                float64
# OSP_Cost                     float64
# Customer Name                 object
# Address Line 1                object
# Address Line 2                object
# Address Line 3                object
# Address Line 4               float64
# ORG                           object
# Extended_Cost                float64
# Material                     float64
# Labor                        float64
# Overhead                     float64
# OSP                          float64
# Total                        float64
# Margin                       float64
# Margin%                      float64
# dtype: object

# %%
# Save to excel file
total_data.to_excel("output/total_data.xlsx")

# %%
# Save file to csv
total_data.to_csv("output/total_data.csv")
